# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 4.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/12.6 MB 3.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/12.6 MB 3.0 MB/s eta 0:00:04
#    ------ --------------------------------- 2.1/12.6 MB 2.6 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.6 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.9/12.6 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.6 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.6 MB 2.4 MB/s eta 0:00:04
# ...

# %%
df = pd.read_csv("../disease.csv")

# %%
df
# Out:
#                              Cure  Cure_Cycle                disease_name  \
# 0                   cure for rust          21                  Apple Rust
# 1              cure for black rot          21             Apple Black rot
# 2                   cure for scab          21                  Apple scab
# 3            cure for bell pepper          21       bell pepper bacterial
# 4         cure for powdery mildew          21       cherry powdery mildew
# 5             cure for black spot          21           citrus black spot
# 6                 cure for canker          21               citrus canker
# 7               cure for greening          21             citrus greening
# 8            cure for common rust          21            corn common rust
# 9         cure for gray leaf spot          21         corn gray leaf spot
# 10  cure for northern leaf blight          21   corn northern leaf blight
# 11         cure for black measles          21         grape black measels
# ...

# %%
import firebase_admin
from firebase_admin import firestore
from firebase_admin import db

# %%
cred = firebase_admin.credentials.Certificate("../fb.json")

# %%
app = firebase_admin.initialize_app(cred)

# %%
DB = firestore.client()

# %%
tdata={
    "chck": "tru",
    "tru": "tru"
}
DB.collection("disease").document("disease").set(tdata)
# Out:
# update_time {
#   seconds: 1732290048
#   nanos: 450324000
# }

# %%
for index, row in df.iterrows():
    data = {
        "cure": row["Cure"],
        "cure_cycle": row["Cure_Cycle"],
        "disease_name": row["disease_name"],
        "domain": row["domain"],
        "diseaseIndex": row["diseaseIndex"],
        "introductions": row["introductions"],
        "symptoms": row["symptoms"],
        "cover_link": row["cover_link"],
        "plantIndex": row["plantIndex"]
    }
    DB.collection("disease").document(row["disease_name"]).set(data)
